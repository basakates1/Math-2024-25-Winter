# %% [markdown]
# <h2><b>SOLUTIONS</b></h2>
# <hr/>
#
# <h4><b>Solution 1:</b></h4>
#
# To find the equation of a plane passing through three points $A(1,2,3)$, $B(3,4,5)$, and $C(2,1,4)$, we'll use the following steps:
#
# 1. Find vectors in the plane: We can start by creating two vectors that lie within the plane, namely $\vec{AB}$ and $\vec{AC}$, using the points given:
#
# $\vec{AB} = B - A = (3 - 1, 4 - 2, 5 - 3) = (2, 2, 2)$
#
# $\vec{AC} = C - A = (2 - 1, 1 - 2, 4 - 3) = (1, -1, 1)$
#
# 2. Find a normal vector to the plane: A normal vector to the plane can be obtained by taking the cross product of $\vec{AB}$ and $\vec{AC}$. The cross product of two vectors $\vec{u} = (u_1, u_2, u_3)$ and $\vec{v} = (v_1, v_2, v_3)$ is calculated as:
#
# $\vec{u} \times \vec{v} = (u_2 v_3 - u_3 v_2, u_3 v_1 - u_1 v_3, u_1 v_2 - u_2 v_1)$
#
# Substituting the components of $\vec{AB}$ and $\vec{AC}$:
#
# $\vec{AB} \times \vec{AC} = (2 \times 1 - 2 \times -1, 2 \times 1 - 2 \times 1, 2 \times -1 - 2 \times 1) = (2+2, 2-2, -2-2) = (4, 0, -4)$
#
# 3. Simplify the normal vector: The vector $(4, 0, -4)$ is a valid normal, but it can be simplified to $(1, 0, -1)$ for the purpose of forming the plane equation.
#
# 4. Formulate the plane equation: The equation of a plane given a normal vector $(A, B, C)$ and a point $(x_1, y_1, z_1)$ on the plane is:
#
# $A(x - x_1) + B(y - y_1) + C(z - z_1) = 0$
#
# Using the simplified normal vector $(1, 0, -1)$ and point $A(1, 2, 3)$:
#
# $1(x - 1) + 0(y - 2) + (-1)(z - 3) = 0$
#
# $x - 1 - z + 3 = 0$
#
# $x - z + 2 = 0$
#
# $x - z = -2$
# or
# $z = x + 2$
#
# Hence, the equation of the plane is $x - z + 2 = 0$ or $z = x+2$.
#
# [![Solution 1](https://i.postimg.cc/FFq8wwXm/1.png)](https://postimg.cc/c6RFn9J5)

# %% [markdown]
# <h4><b>Solution 2:</b></h4>
#
# **Step 1: Identify the Normal Vector**
#
# Since the desired plane is parallel to the given plane, it shares the same normal vector. The normal vector of the given plane $2x+3y+4z=5$ is $\vec{n}=(2,3,4)$.
#
# **Step 2: Use the Point-Normal Form of the Plane Equation**
#
# The general equation of a plane using the point-normal form is: $ax+by+cz=d$ where $(a,b,c)$ is the normal vector and $d$ is a constant determined based on a specific point through which the plane passes.
#
# **Step 3: Substitute the Point $A$ and Solve for $d$**
#
# To find $d$, substitute the point $A(1,2,3)$ into the plane equation:
#
# $2 \times 1 + 3 \times 2 + 4 \times 3 = d$
#
# $2+6+12=d$
#
# $d=20$
#
# **Conclusion**
#
# Thus, the equation of the plane passing through point $A(1,2,3)$ and parallel to the plane $2x+3y+4z=5$ is:
#
# $2x+3y+4z=20$
#
# This plane shares the same normal vector with the given plane and passes through the specified point, ensuring that it is indeed parallel and correctly positioned in space.
#
# [![Solution 2](https://i.postimg.cc/434TXM4d/2.png)](https://postimg.cc/rDHHJfrX)

# %% [markdown]
# <h4><b>Solution 3:</b></h4>
#
# To find the equation of the plane that passes through a given point and is perpendicular to a given normal vector, you can use the general form of the equation of a plane:
#
# $ax+by+cz=d$
#
# where $(a,b,c)$ are the components of the normal vector to the plane, and $d$ is a constant that can be determined using the given point through which the plane passes.
#
# Given:
#
# The normal vector, $\vec{n}=[2,3,4]$, thus $a=2$, $b=3$, and $c=4$.
#
# The plane passes through point $A(1,2,3)$.
#
# Substitute the point $A(1,2,3)$ into the plane equation to solve for $d$:
#
# $2(1)+3(2)+4(3)=d$
#
# $2+6+12=d$
#
# $d=20$
#
# Thus, the equation of the plane is:
#
# $2x+3y+4z=20$
#
# [![Solution 3](https://i.postimg.cc/L6tZgYSW/3.png)](https://postimg.cc/XpvvTvpK)

# %% [markdown]
# <h4><b>Solution 4:</b></h4>
#
# **Step 1: Find the Direction Vector**
#
# The direction vector of the line of intersection can be found using the cross product of the normal vectors of the two planes.
#
# The normal vector of the first plane $2x+3y+4z=5$ is $\mathbf{n}_1 = (2, 3, 4)$.
#
# The normal vector of the second plane $3x+4y+2z=6$ is $\mathbf{n}_2 = (3, 4, 2)$.
#
# The cross product of these two vectors, $\mathbf{n}_1 \times \mathbf{n}_2$, gives us the direction vector of the line of intersection:
#
# $\mathbf{n}_1 \times \mathbf{n}_2 = \begin{vmatrix} \mathbf{i} & \mathbf{j} & \mathbf{k} \\ 2 & 3 & 4 \\ 3 & 4 & 2 \end{vmatrix}$
#
# **Step 2: Calculate the Cross Product**
#
# $\mathbf{i}(3*2 - 4*4) - \mathbf{j}(2*2 - 4*3) + \mathbf{k}(2*4 - 3*3)$
#
# $= \mathbf{i}(6 - 16) - \mathbf{j}(4 - 12) + \mathbf{k}(8 - 9)$
#
# $= -10\mathbf{i} + 8\mathbf{j} - \mathbf{k}$
#
# $= (-10, 8, -1)$
#
# **Step 3: Find a Point on the Line**
#
# We need a point that lies on both planes. We can do this by setting one of the variables to a convenient value (such as $z=0$) and solving for the other two variables:
#
# Setting $z=0$ in both equations:
#
# $2x+3y=5$
#
# $3x+4y=6$
#
# **Step 4: Solve the Equations**
#
# Let's solve this system of equations using matrix operations or the substitution method to find $x$ and $y$.
#
# The solution to the equations with $z=0$ is $x=-2$ and $y=3$. Thus, a point on the line of intersection is $(-2, 3, 0)$.
#
# **Step 5: Equation of the Line**
#
# The equation of the line can be described in parametric form using the point $(-2, 3, 0)$ and the direction vector $(-10, 8, -1)$:
#
# $x = -2 - 10t,$
#
# $y = 3 + 8t,$
#
# $z = -t.$
#
# [![Solution 4](https://i.postimg.cc/bwF6WF5k/4.png)](https://postimg.cc/CRkHfJSx)

# %% [markdown]
# <h4><b>Solution 5</b></h4>
#
# To find the equation of the plane passing through a point and parallel to two given vectors, we can follow these steps:
#
# 1.  Find the normal vector to the plane by taking the cross product of the two parallel vectors.
#
# 2.  Use the point-normal form of the plane's equation: $(x - x_0, y - y_0, z - z_0) \cdot \vec{n} = 0$, where $\vec{n}$ is the normal vector and $(x_0, y_0, z_0)$ is a point through which the plane passes.
#
# Let's start by finding the normal vector to the plane using the cross product of vectors $\vec{v_1} = [1, 0, 1]$ and $\vec{v_2} = [0, 1, -1]$:
#
# $\vec{v_1} \times \vec{v_2} = \begin{vmatrix} \mathbf{i} & \mathbf{j} & \mathbf{k} \\ 1 & 0 & 1 \\ 0 & 1 & -1 \end{vmatrix}$
#
# The determinant for each component is calculated as:
#
# *   i-component: $0 \cdot (-1) - 1 \cdot 1 = -1$
# *   j-component: $1 \cdot (-1) - 1 \cdot 0 = -1$. However, remember that the j-component in the cross product has a negative sign in front of it, so it becomes $-(-1) = 1$
# *   k-component: $1 \cdot 1 - 0 \cdot 0 = 1$
#
# So, the cross product $\vec{n} = [-1, 1, 1]$.
#
# Now, using the point-normal form of the plane's equation with point $A(1, 2, 3)$ and normal vector $\vec{n} = [-1, 1, 1]$, we have:
#
# $-1(x - 1) + 1(y - 2) + 1(z - 3) = 0$
#
# $-x + 1 + y - 2 + z - 3 = 0$
#
# $-x + y + z - 4 = 0$
#
# Hence, the equation of the plane is:
#
# $-x + y + z = 4$ or $x - y - z = -4$
#
# This equation represents the plane passing through the point $(1, 2, 3)$ and parallel to the vectors $\vec{v_1}$ and $\vec{v_2}$.
#
# [![Solution 5](https://i.postimg.cc/qqsyrQGk/5.png)](https://postimg.cc/D4z8drDD)

# %% [markdown]
# <h4><b>Solution 6</b></h4>
#
# **Parallel Plane**
#
# A plane that is parallel to another has the same normal vector. The given plane is:
#
# $2x + 3y + 4z = 5$
#
# The normal vector of this plane is $\mathbf{n} = (2, 3, 4)$.
#
# Any plane with the same normal vector is parallel. We can change the constant on the right side of the equation to get a different plane:
#
# $2x + 3y + 4z = k$
#
# where $k \ne 5$ (to ensure it's not the same plane). Let's pick $k = 10$ as an example:
#
# $2x + 3y + 4z = 10$
#
# **Perpendicular Plane**
#
# A plane that is perpendicular to another will have a normal vector that is perpendicular to the normal vector of the given plane. The dot product of the normal vectors of two perpendicular planes equals zero:
#
# $\mathbf{n}_1 \cdot \mathbf{n}_2 = 0$
#
# Let’s assume a normal vector for the perpendicular plane as $\mathbf{n}_2 = (a, b, c)$. It must satisfy:
#
# $2a + 3b + 4c = 0$
#
# Choosing simple values that satisfy this, let $a = 4$, $b = -4$, and $c = 1$ (since $2(4) + 3(-4) + 4(1) = 8 - 12 + 4 = 0$), we get the normal vector $(4, -4, 1)$ for the perpendicular plane. The equation of the perpendicular plane can be written as:
#
# $4x - 4y + z = d$
#
# where $d$ can be any constant. Let's choose $d = 0$ for simplicity:
#
# $4x - 4y + z = 0$
#
# **Summary**
#
# Parallel Plane: $2x + 3y + 4z = 10$
#
# Perpendicular Plane: $4x - 4y + z = 0$
#
# [![Solution 6](https://i.postimg.cc/44Wh6KF2/output-17.png)](https://postimg.cc/kDt495CW)

# %%
## Visualization for Solution 5

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the figure and 3D axis
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Define ranges for x and y
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)
X, Y = np.meshgrid(x, y)

# Original plane: 2x + 3y + 4z = 5
Z1 = (5 - 2 * X - 3 * Y) / 4

# Parallel plane: 2x + 3y + 4z = 10
Z2 = (10 - 2 * X - 3 * Y) / 4

# Perpendicular plane: 4x - 4y + z = 0
Z3 = 4 * X - 4 * Y

# Plotting the original plane
ax.plot_surface(X, Y, Z1, alpha=0.5, rstride=100, cstride=100, color='r', edgecolor='none')

# Plotting the parallel plane
ax.plot_surface(X, Y, Z2, alpha=0.5, rstride=100, cstride=100, color='g', edgecolor='none')

# Plotting the perpendicular plane
ax.plot_surface(X, Y, Z3, alpha=0.5, rstride=100, cstride=100, color='b', edgecolor='none')

# Labels and title
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
ax.set_title('Visualization of Planes')

# Set the viewing angle for better visualization
ax.view_init(elev=30, azim=30)

# Show the plot
plt.show()

# %% [markdown]
# <h4><b>Solution 7</b></h4>
#
# Identifying the Components: We are given the plane equation $2x + 3y + 4z = 5$ and the point $A(1, 2, 3)$.
#
# Using the Distance Formula: The formula to calculate the distance $d$ from a point $(x_1, y_1, z_1)$ to a plane $Ax + By + Cz + D = 0$ is:
#
# $d = \frac{|Ax_1 + By_1 + Cz_1 + D|}{\sqrt{A^2 + B^2 + C^2}}$
#
# In this case, $A = 2$, $B = 3$, $C = 4$, and $D = -5$ (rewriting the plane equation in standard form $2x + 3y + 4z - 5 = 0$).
#
# Substituting the Values:
#
# $d = \frac{|2 \cdot 1 + 3 \cdot 2 + 4 \cdot 3 - 5|}{\sqrt{2^2 + 3^2 + 4^2}}$
#
# $d = \frac{|2 + 6 + 12 - 5|}{\sqrt{4 + 9 + 16}}$
#
# $d = \frac{|15|}{\sqrt{29}}$
#
# $d = \frac{15}{\sqrt{29}} \approx \frac{15}{5.385} \approx 2.785$
#
# So, the distance from point $A$ to the plane is approximately 2.785 units.
#
# [![Solution 7](https://i.postimg.cc/T1cw3s53/7.png)](https://postimg.cc/30d7LnZs)

# %% [markdown]
# <h4><b>Solution 8</b></h4>
#
# ***Step 1: Vectors in the Plane***
#
# First, we can form two vectors that lie within the plane using these three points:
#
# Vector $\mathbf{AB} = B - A = (0 - 2, 3 - 0, 0 - 0) = (-2, 3, 0)$
#
# Vector $\mathbf{AC} = C - A = (0 - 2, 0 - 0, 4 - 0) = (-2, 0, 4)$
#
# ***Step 2: Normal Vector***
#
# The normal vector to the plane, $\mathbf{n}$, can be found by taking the cross product of vectors $\mathbf{AB}$ and $\mathbf{AC}$.
#
# $\mathbf{n} = \mathbf{AB} \times \mathbf{AC} = \begin{vmatrix} \mathbf{i} & \mathbf{j} & \mathbf{k} \\ -2 & 3 & 0 \\ -2 & 0 & 4 \end{vmatrix}$
#
# Calculating the determinant,
#
# $\mathbf{n} = \mathbf{i}(3 \cdot 4 - 0 \cdot 0) - \mathbf{j}(-2 \cdot 4 - (-2) \cdot 0) + \mathbf{k}(-2 \cdot 0 - 3 \cdot (-2))$
#
# $\mathbf{n} = 12\mathbf{i} + 8\mathbf{j} + 6\mathbf{k} = (12, 8, 6)$
#
# To simplify, divide by 2:
#
# $\mathbf{n} = (6, 4, 3)$
#
# ***Step 3: Equation of the Plane***
#
# The general equation of a plane given a normal vector $\mathbf{n} = (a, b, c)$ and a point $(x_1, y_1, z_1)$ on the plane is:
#
# $a(x - x_1) + b(y - y_1) + c(z - z_1) = 0$
#
# Using point $A(2, 0, 0)$ and normal vector $(6, 4, 3)$:
#
# $6(x - 2) + 4y + 3z = 0$
#
# $6x - 12 + 4y + 3z = 0$
#
# $6x + 4y + 3z = 12$
#
# Thus, the equation of the plane is:
#
# $6x + 4y + 3z = 12$
#
# [![Solution 8](https://i.postimg.cc/Y2VGj5Ph/8.png)](https://postimg.cc/23Q8KKrD)

# %% [markdown]
# <h4><b>Solution 9</b></h4>
#
# To find the angle between two planes, you can use the normals of the planes. The angle between the planes is the same as the angle between their normal vectors.
#
# For the planes:
#
# $x + y + z = 1$ has the normal vector $\mathbf{n}_1 = (1, 1, 1)$.
#
# $x = 0$ (which is the $yz$-plane) has the normal vector $\mathbf{n}_2 = (1, 0, 0)$.
#
# The angle $\theta$ between two vectors $\mathbf{a}$ and $\mathbf{b}$ can be found using the dot product formula:
#
# $\cos \theta = \frac{\mathbf{a} \cdot \mathbf{b}}{\|\mathbf{a}\| \|\mathbf{b}\|}$
#
# Here, the dot product $\mathbf{n}_1 \cdot \mathbf{n}_2 = 1 \cdot 1 + 1 \cdot 0 + 1 \cdot 0 = 1$ and the magnitudes $\|\mathbf{n}_1\| = \sqrt{1^2 + 1^2 + 1^2} = \sqrt{3}$ and $\|\mathbf{n}_2\| = \sqrt{1^2} = 1$.
#
# Thus,
#
# $\cos \theta = \frac{1}{\sqrt{3} \cdot 1} = \frac{1}{\sqrt{3}} = \frac{\sqrt{3}}{3}$
#
# $\theta = \cos^{-1}\left(\frac{\sqrt{3}}{3}\right)$
#
# The angle between the plane $x + y + z = 1$ and the $yz$-plane ($x = 0$) is approximately $54.74^\circ$.
#
# [![Solution 9](https://i.postimg.cc/HLB0NSkX/output-18.png)](https://postimg.cc/7CJTGn7Z)

# %%
# Solution 9 Visualization

# Setting up the plot again
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Plane x + y + z = 1
ax.plot_surface(x, y, z1, alpha=0.5, rstride=100, cstride=100, color='b', edgecolor='k', label='x + y + z = 1')

# yz-plane (x = 0)
ax.plot_surface(np.zeros_like(x), y, x, alpha=0.5, rstride=100, cstride=100, color='r', edgecolor='k', label='x = 0')

# Add normal vectors as text labels
ax.quiver(0, 0, 0, 1, 1, 1, color='k', length=0.5, normalize=True)
ax.text(0.6, 0.6, 0.6, "n1 (1, 1, 1)", color='k', fontsize=10)

ax.quiver(0, 0, 0, 1, 0, 0, color='k', length=0.5, normalize=True)
ax.text(0.6, 0, 0, "n2 (1, 0, 0)", color='k', fontsize=10)

# Add angle text
ax.text(0.3, 0.1, 0.1, r"$54.74^\circ$", color="k", fontsize=12)

# Annotations and labels
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
ax.set_title('Angle Between Planes')

# Legend
plane1 = plt.Rectangle((0, 0), 1, 1, fc="b", alpha=0.5)
plane2 = plt.Rectangle((0, 0), 1, 1, fc="r", alpha=0.5)
ax.legend([plane1, plane2], ['x + y + z = 1', 'x = 0'])

plt.show()

# %% [markdown]
# <h4><b>Solution 10</b></h4>
#
# To find a vector perpendicular to the plane given by the equation $x + y + z = 1$, you need to determine the normal vector of the plane. The normal vector is a vector that is perpendicular to every line that lies on the plane.
#
# For the equation of a plane in the form $Ax + By + Cz = D$, the coefficients $A$, $B$, and $C$ form the components of a vector normal to the plane. In your case, the equation $x + y + z = 1$ can be seen as $1x + 1y + 1z = 1$. Thus, the normal vector $\mathbf{n}$ is:
#
# $\mathbf{n} = \begin{pmatrix} 1 \\ 1 \\ 1 \end{pmatrix}$
#
# This vector $(1, 1, 1)$ is perpendicular to the plane $x + y + z = 1$.
#
# [![Solution 10](https://i.postimg.cc/G2gWbJqs/output-20.png)](https://postimg.cc/FdcWZct9)
